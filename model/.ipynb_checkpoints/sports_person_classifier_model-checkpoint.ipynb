# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_image/img4.jpg')

# %%
img.shape
# Out:
# (594, 396, 3)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (594, 396)

# %%
gray
# Out:
# array([[151, 151, 151, ..., 147, 147, 147],
#        [151, 151, 151, ..., 147, 147, 147],
#        [151, 151, 151, ..., 147, 147, 147],
#        ...,
#        [136, 136, 136, ..., 137, 137, 137],
#        [138, 138, 137, ..., 137, 137, 137],
#        [138, 138, 137, ..., 137, 137, 137]], dtype=uint8)

# %%
plt.imshow(gray , cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')


faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[145,  55,  97,  97]], dtype=int32)

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (145, 55, 97, 97)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    face_image= cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_image[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.figure()
plt.imshow(face_image , cmap='gray')

# %%
# %matplotlib inline
plt.imshow(roi_color ,cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if(img is not None):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                return roi_color

# %%
original_image = cv2.imread('./test_image/img4.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_image/img4.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_image/img5.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_image/img5.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/zx/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
        print(entry.path)
# Out:
# ./dataset/messi
# ./dataset/pandaya
# ./dataset/ronaldo
# ./dataset/sharapova
# ./dataset/virat_kohli
# ./dataset/zx

# %%
img_dirs
# Out:
# ['./dataset/messi',
#  './dataset/pandaya',
#  './dataset/ronaldo',
#  './dataset/sharapova',
#  './dataset/virat_kohli',
#  './dataset/zx']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# messi
# Generating cropped images in folder:  ./dataset/zx/messi
# pandaya
# Generating cropped images in folder:  ./dataset/zx/pandaya
# ronaldo
# Generating cropped images in folder:  ./dataset/zx/ronaldo
# sharapova
# Generating cropped images in folder:  ./dataset/zx/sharapova
# virat_kohli
# Generating cropped images in folder:  ./dataset/zx/virat_kohli
# zx

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'messi': ['./dataset/zx/messi\\messi1.png',
#   './dataset/zx/messi\\messi10.png',
#   './dataset/zx/messi\\messi11.png',
#   './dataset/zx/messi\\messi13.png',
#   './dataset/zx/messi\\messi14.png',
#   './dataset/zx/messi\\messi16.png',
#   './dataset/zx/messi\\messi17.png',
#   './dataset/zx/messi\\messi18.png',
#   './dataset/zx/messi\\messi19.png',
#   './dataset/zx/messi\\messi2.png',
#   './dataset/zx/messi\\messi20.png',
#   './dataset/zx/messi\\messi21.png',
#   './dataset/zx/messi\\messi22.png',
#   './dataset/zx/messi\\messi23.png',
#   './dataset/zx/messi\\messi24.png',
#   './dataset/zx/messi\\messi25.png',
#   './dataset/zx/messi\\messi26.png',
#   './dataset/zx/messi\\messi27.png',
#   './dataset/zx/messi\\messi28.png',
#   './dataset/zx/messi\\messi29.png',
#   './dataset/zx/messi\\messi3.png',
#   './dataset/zx/messi\\messi30.png',
#   './dataset/zx/messi\\messi31.png',
#   './dataset/zx/messi\\messi32.png',
#   './dataset/zx/messi\\messi33.png',
#   './dataset/zx/messi\\messi34.png',
#   './dataset/zx/messi\\messi35.png',
#   './dataset/zx/messi\\messi36.png',
#   './dataset/zx/messi\\messi37.png',
#   './dataset/zx/messi\\messi38.png',
#   './dataset/zx/messi\\messi39.png',
#   './dataset/zx/messi\\messi4.png',
#   './dataset/zx/messi\\messi40.png',
#   './dataset/zx/messi\\messi41.png',
#   './dataset/zx/messi\\messi42.png',
#   './dataset/zx/messi\\messi43.png',
#   './dataset/zx/messi\\messi44.png',
#   './dataset/zx/messi\\messi45.png',
#   './dataset/zx/messi\\messi46.png',
#   './dataset/zx/messi\\messi47.png',
#   './dataset/zx/messi\\messi48.png',
#   './dataset/zx/messi\\messi49.png',
#   './dataset/zx/messi\\messi5.png',
#   './dataset/zx/messi\\messi50.png',
#   './dataset/zx/messi\\messi52.png',
#   './dataset/zx/messi\\messi53.png',
#   './dataset/zx/messi\\messi54.png',
#   './dataset/zx/messi\\messi55.png',
#   './dataset/zx/messi\\messi57.png',
#   './dataset/zx/messi\\messi58.png',
#   './dataset/zx/messi\\messi6.png',
#   './dataset/zx/messi\\messi60.png',
#   './dataset/zx/messi\\messi62.png',
#   './dataset/zx/messi\\messi65.png',
#   './dataset/zx/messi\\messi66.png',
#   './dataset/zx/messi\\messi68.png',
#   './dataset/zx/messi\\messi69.png',
#   './dataset/zx/messi\\messi7.png',
#   './dataset/zx/messi\\messi71.png',
#   './dataset/zx/messi\\messi72.png',
#   './dataset/zx/messi\\messi73.png',
#   './dataset/zx/messi\\messi74.png',
#   './dataset/zx/messi\\messi75.png',
#   './dataset/zx/messi\\messi76.png',
#   './dataset/zx/messi\\messi77.png',
#   './dataset/zx/messi\\messi78.png',
#   './dataset/zx/messi\\messi79.png',
#   './dataset/zx/messi\\messi8.png',
#   './dataset/zx/messi\\messi80.png',
#   './dataset/zx/messi\\messi9.png'],
#  'pandaya': ['./dataset/zx/pandaya\\pandaya1.png',
#   './dataset/zx/pandaya\\pandaya10.png',
#   './dataset/zx/pandaya\\pandaya12.png',
#   './dataset/zx/pandaya\\pandaya14.png',
#   './dataset/zx/pandaya\\pandaya15.png',
#   './dataset/zx/pandaya\\pandaya16.png',
#   './dataset/zx/pandaya\\pandaya18.png',
#   './dataset/zx/pandaya\\pandaya19.png',
#   './dataset/zx/pandaya\\pandaya2.png',
#   './dataset/zx/pandaya\\pandaya20.png',
#   './dataset/zx/pandaya\\pandaya22.png',
#   './dataset/zx/pandaya\\pandaya23.png',
#   './dataset/zx/pandaya\\pandaya24.png',
#   './dataset/zx/pandaya\\pandaya25.png',
#   './dataset/zx/pandaya\\pandaya26.png',
#   './dataset/zx/pandaya\\pandaya27.png',
#   './dataset/zx/pandaya\\pandaya30.png',
#   './dataset/zx/pandaya\\pandaya31.png',
#   './dataset/zx/pandaya\\pandaya32.png',
#   './dataset/zx/pandaya\\pandaya33.png',
#   './dataset/zx/pandaya\\pandaya34.png',
#   './dataset/zx/pandaya\\pandaya35.png',
#   './dataset/zx/pandaya\\pandaya36.png',
#   './dataset/zx/pandaya\\pandaya37.png',
#   './dataset/zx/pandaya\\pandaya4.png',
#   './dataset/zx/pandaya\\pandaya6.png',
#   './dataset/zx/pandaya\\pandaya7.png',
#   './dataset/zx/pandaya\\pandaya8.png',
#   './dataset/zx/pandaya\\pandaya9.png'],
#  'ronaldo': ['./dataset/zx/ronaldo\\ronaldo1.png',
#   './dataset/zx/ronaldo\\ronaldo10.png',
#   './dataset/zx/ronaldo\\ronaldo11.png',
#   './dataset/zx/ronaldo\\ronaldo12.png',
#   './dataset/zx/ronaldo\\ronaldo13.png',
#   './dataset/zx/ronaldo\\ronaldo14.png',
#   './dataset/zx/ronaldo\\ronaldo15.png',
#   './dataset/zx/ronaldo\\ronaldo17.png',
#   './dataset/zx/ronaldo\\ronaldo18.png',
#   './dataset/zx/ronaldo\\ronaldo2.png',
#   './dataset/zx/ronaldo\\ronaldo20.png',
#   './dataset/zx/ronaldo\\ronaldo21.png',
#   './dataset/zx/ronaldo\\ronaldo22.png',
#   './dataset/zx/ronaldo\\ronaldo24.png',
#   './dataset/zx/ronaldo\\ronaldo25.png',
#   './dataset/zx/ronaldo\\ronaldo26.png',
#   './dataset/zx/ronaldo\\ronaldo27.png',
#   './dataset/zx/ronaldo\\ronaldo28.png',
#   './dataset/zx/ronaldo\\ronaldo29.png',
#   './dataset/zx/ronaldo\\ronaldo30.png',
#   './dataset/zx/ronaldo\\ronaldo31.png',
#   './dataset/zx/ronaldo\\ronaldo32.png',
#   './dataset/zx/ronaldo\\ronaldo33.png',
#   './dataset/zx/ronaldo\\ronaldo34.png',
#   './dataset/zx/ronaldo\\ronaldo35.png',
#   './dataset/zx/ronaldo\\ronaldo36.png',
#   './dataset/zx/ronaldo\\ronaldo37.png',
#   './dataset/zx/ronaldo\\ronaldo38.png',
#   './dataset/zx/ronaldo\\ronaldo39.png',
#   './dataset/zx/ronaldo\\ronaldo4.png',
#   './dataset/zx/ronaldo\\ronaldo40.png',
#   './dataset/zx/ronaldo\\ronaldo41.png',
#   './dataset/zx/ronaldo\\ronaldo42.png',
#   './dataset/zx/ronaldo\\ronaldo43.png',
#   './dataset/zx/ronaldo\\ronaldo44.png',
#   './dataset/zx/ronaldo\\ronaldo45.png',
#   './dataset/zx/ronaldo\\ronaldo46.png',
#   './dataset/zx/ronaldo\\ronaldo47.png',
#   './dataset/zx/ronaldo\\ronaldo48.png',
#   './dataset/zx/ronaldo\\ronaldo49.png',
#   './dataset/zx/ronaldo\\ronaldo5.png',
#   './dataset/zx/ronaldo\\ronaldo50.png',
#   './dataset/zx/ronaldo\\ronaldo51.png',
#   './dataset/zx/ronaldo\\ronaldo6.png',
#   './dataset/zx/ronaldo\\ronaldo7.png',
#   './dataset/zx/ronaldo\\ronaldo8.png',
#   './dataset/zx/ronaldo\\ronaldo9.png'],
#  'sharapova': ['./dataset/zx/sharapova\\sharapova1.png',
#   './dataset/zx/sharapova\\sharapova10.png',
#   './dataset/zx/sharapova\\sharapova11.png',
#   './dataset/zx/sharapova\\sharapova12.png',
#   './dataset/zx/sharapova\\sharapova13.png',
#   './dataset/zx/sharapova\\sharapova14.png',
#   './dataset/zx/sharapova\\sharapova15.png',
#   './dataset/zx/sharapova\\sharapova16.png',
#   './dataset/zx/sharapova\\sharapova17.png',
#   './dataset/zx/sharapova\\sharapova18.png',
#   './dataset/zx/sharapova\\sharapova19.png',
#   './dataset/zx/sharapova\\sharapova2.png',
#   './dataset/zx/sharapova\\sharapova20.png',
#   './dataset/zx/sharapova\\sharapova21.png',
#   './dataset/zx/sharapova\\sharapova22.png',
#   './dataset/zx/sharapova\\sharapova23.png',
#   './dataset/zx/sharapova\\sharapova24.png',
#   './dataset/zx/sharapova\\sharapova25.png',
#   './dataset/zx/sharapova\\sharapova26.png',
#   './dataset/zx/sharapova\\sharapova27.png',
#   './dataset/zx/sharapova\\sharapova29.png',
#   './dataset/zx/sharapova\\sharapova3.png',
#   './dataset/zx/sharapova\\sharapova30.png',
#   './dataset/zx/sharapova\\sharapova31.png',
#   './dataset/zx/sharapova\\sharapova32.png',
#   './dataset/zx/sharapova\\sharapova4.png',
#   './dataset/zx/sharapova\\sharapova5.png',
#   './dataset/zx/sharapova\\sharapova6.png',
#   './dataset/zx/sharapova\\sharapova8.png',
#   './dataset/zx/sharapova\\sharapova9.png'],
#  'virat_kohli': ['./dataset/zx/virat_kohli\\virat_kohli1.png',
#   './dataset/zx/virat_kohli\\virat_kohli11.png',
#   './dataset/zx/virat_kohli\\virat_kohli12.png',
#   './dataset/zx/virat_kohli\\virat_kohli13.png',
#   './dataset/zx/virat_kohli\\virat_kohli14.png',
#   './dataset/zx/virat_kohli\\virat_kohli15.png',
#   './dataset/zx/virat_kohli\\virat_kohli16.png',
#   './dataset/zx/virat_kohli\\virat_kohli17.png',
#   './dataset/zx/virat_kohli\\virat_kohli19.png',
#   './dataset/zx/virat_kohli\\virat_kohli20.png',
#   './dataset/zx/virat_kohli\\virat_kohli21.png',
#   './dataset/zx/virat_kohli\\virat_kohli22.png',
#   './dataset/zx/virat_kohli\\virat_kohli25.png',
#   './dataset/zx/virat_kohli\\virat_kohli26.png',
#   './dataset/zx/virat_kohli\\virat_kohli27.png',
#   './dataset/zx/virat_kohli\\virat_kohli28.png',
#   './dataset/zx/virat_kohli\\virat_kohli29.png',
#   './dataset/zx/virat_kohli\\virat_kohli3.png',
#   './dataset/zx/virat_kohli\\virat_kohli30.png',
#   './dataset/zx/virat_kohli\\virat_kohli31.png',
#   './dataset/zx/virat_kohli\\virat_kohli32.png',
#   './dataset/zx/virat_kohli\\virat_kohli33.png',
#   './dataset/zx/virat_kohli\\virat_kohli34.png',
#   './dataset/zx/virat_kohli\\virat_kohli35.png',
#   './dataset/zx/virat_kohli\\virat_kohli36.png',
#   './dataset/zx/virat_kohli\\virat_kohli38.png',
#   './dataset/zx/virat_kohli\\virat_kohli39.png',
#   './dataset/zx/virat_kohli\\virat_kohli4.png',
#   './dataset/zx/virat_kohli\\virat_kohli5.png',
#   './dataset/zx/virat_kohli\\virat_kohli6.png',
#   './dataset/zx/virat_kohli\\virat_kohli7.png',
#   './dataset/zx/virat_kohli\\virat_kohli8.png',
#   './dataset/zx/virat_kohli\\virat_kohli9.png']}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'messi': ['./dataset/zx/messi\\messi1.png',
#   './dataset/zx/messi\\messi10.png',
#   './dataset/zx/messi\\messi11.png',
#   './dataset/zx/messi\\messi13.png',
#   './dataset/zx/messi\\messi14.png',
#   './dataset/zx/messi\\messi16.png',
#   './dataset/zx/messi\\messi17.png',
#   './dataset/zx/messi\\messi18.png',
#   './dataset/zx/messi\\messi19.png',
#   './dataset/zx/messi\\messi2.png',
#   './dataset/zx/messi\\messi20.png',
#   './dataset/zx/messi\\messi21.png',
#   './dataset/zx/messi\\messi22.png',
#   './dataset/zx/messi\\messi23.png',
#   './dataset/zx/messi\\messi24.png',
#   './dataset/zx/messi\\messi25.png',
#   './dataset/zx/messi\\messi26.png',
#   './dataset/zx/messi\\messi27.png',
#   './dataset/zx/messi\\messi28.png',
#   './dataset/zx/messi\\messi29.png',
#   './dataset/zx/messi\\messi3.png',
#   './dataset/zx/messi\\messi30.png',
#   './dataset/zx/messi\\messi31.png',
#   './dataset/zx/messi\\messi32.png',
#   './dataset/zx/messi\\messi33.png',
#   './dataset/zx/messi\\messi34.png',
#   './dataset/zx/messi\\messi35.png',
#   './dataset/zx/messi\\messi36.png',
#   './dataset/zx/messi\\messi37.png',
#   './dataset/zx/messi\\messi38.png',
#   './dataset/zx/messi\\messi39.png',
#   './dataset/zx/messi\\messi4.png',
#   './dataset/zx/messi\\messi40.png',
#   './dataset/zx/messi\\messi41.png',
#   './dataset/zx/messi\\messi42.png',
#   './dataset/zx/messi\\messi43.png',
#   './dataset/zx/messi\\messi44.png',
#   './dataset/zx/messi\\messi45.png',
#   './dataset/zx/messi\\messi46.png',
#   './dataset/zx/messi\\messi47.png',
#   './dataset/zx/messi\\messi48.png',
#   './dataset/zx/messi\\messi49.png',
#   './dataset/zx/messi\\messi5.png',
#   './dataset/zx/messi\\messi50.png',
#   './dataset/zx/messi\\messi52.png',
#   './dataset/zx/messi\\messi53.png',
#   './dataset/zx/messi\\messi54.png',
#   './dataset/zx/messi\\messi55.png',
#   './dataset/zx/messi\\messi57.png',
#   './dataset/zx/messi\\messi58.png',
#   './dataset/zx/messi\\messi6.png',
#   './dataset/zx/messi\\messi60.png',
#   './dataset/zx/messi\\messi62.png',
#   './dataset/zx/messi\\messi65.png',
#   './dataset/zx/messi\\messi66.png',
#   './dataset/zx/messi\\messi68.png',
#   './dataset/zx/messi\\messi69.png',
#   './dataset/zx/messi\\messi7.png',
#   './dataset/zx/messi\\messi71.png',
#   './dataset/zx/messi\\messi72.png',
#   './dataset/zx/messi\\messi73.png',
#   './dataset/zx/messi\\messi74.png',
#   './dataset/zx/messi\\messi75.png',
#   './dataset/zx/messi\\messi76.png',
#   './dataset/zx/messi\\messi77.png',
#   './dataset/zx/messi\\messi78.png',
#   './dataset/zx/messi\\messi79.png',
#   './dataset/zx/messi\\messi8.png',
#   './dataset/zx/messi\\messi80.png',
#   './dataset/zx/messi\\messi9.png'],
#  'pandaya': ['./dataset/zx/pandaya\\pandaya1.png',
#   './dataset/zx/pandaya\\pandaya10.png',
#   './dataset/zx/pandaya\\pandaya12.png',
#   './dataset/zx/pandaya\\pandaya14.png',
#   './dataset/zx/pandaya\\pandaya15.png',
#   './dataset/zx/pandaya\\pandaya16.png',
#   './dataset/zx/pandaya\\pandaya18.png',
#   './dataset/zx/pandaya\\pandaya19.png',
#   './dataset/zx/pandaya\\pandaya2.png',
#   './dataset/zx/pandaya\\pandaya20.png',
#   './dataset/zx/pandaya\\pandaya22.png',
#   './dataset/zx/pandaya\\pandaya23.png',
#   './dataset/zx/pandaya\\pandaya24.png',
#   './dataset/zx/pandaya\\pandaya25.png',
#   './dataset/zx/pandaya\\pandaya26.png',
#   './dataset/zx/pandaya\\pandaya27.png',
#   './dataset/zx/pandaya\\pandaya30.png',
#   './dataset/zx/pandaya\\pandaya31.png',
#   './dataset/zx/pandaya\\pandaya32.png',
#   './dataset/zx/pandaya\\pandaya33.png',
#   './dataset/zx/pandaya\\pandaya34.png',
#   './dataset/zx/pandaya\\pandaya35.png',
#   './dataset/zx/pandaya\\pandaya36.png',
#   './dataset/zx/pandaya\\pandaya37.png',
#   './dataset/zx/pandaya\\pandaya4.png',
#   './dataset/zx/pandaya\\pandaya6.png',
#   './dataset/zx/pandaya\\pandaya7.png',
#   './dataset/zx/pandaya\\pandaya8.png',
#   './dataset/zx/pandaya\\pandaya9.png'],
#  'ronaldo': ['./dataset/zx/ronaldo\\ronaldo1.png',
#   './dataset/zx/ronaldo\\ronaldo10.png',
#   './dataset/zx/ronaldo\\ronaldo11.png',
#   './dataset/zx/ronaldo\\ronaldo12.png',
#   './dataset/zx/ronaldo\\ronaldo13.png',
#   './dataset/zx/ronaldo\\ronaldo14.png',
#   './dataset/zx/ronaldo\\ronaldo15.png',
#   './dataset/zx/ronaldo\\ronaldo17.png',
#   './dataset/zx/ronaldo\\ronaldo18.png',
#   './dataset/zx/ronaldo\\ronaldo2.png',
#   './dataset/zx/ronaldo\\ronaldo20.png',
#   './dataset/zx/ronaldo\\ronaldo21.png',
#   './dataset/zx/ronaldo\\ronaldo22.png',
#   './dataset/zx/ronaldo\\ronaldo24.png',
#   './dataset/zx/ronaldo\\ronaldo25.png',
#   './dataset/zx/ronaldo\\ronaldo26.png',
#   './dataset/zx/ronaldo\\ronaldo27.png',
#   './dataset/zx/ronaldo\\ronaldo28.png',
#   './dataset/zx/ronaldo\\ronaldo29.png',
#   './dataset/zx/ronaldo\\ronaldo30.png',
#   './dataset/zx/ronaldo\\ronaldo31.png',
#   './dataset/zx/ronaldo\\ronaldo32.png',
#   './dataset/zx/ronaldo\\ronaldo33.png',
#   './dataset/zx/ronaldo\\ronaldo34.png',
#   './dataset/zx/ronaldo\\ronaldo35.png',
#   './dataset/zx/ronaldo\\ronaldo36.png',
#   './dataset/zx/ronaldo\\ronaldo37.png',
#   './dataset/zx/ronaldo\\ronaldo38.png',
#   './dataset/zx/ronaldo\\ronaldo39.png',
#   './dataset/zx/ronaldo\\ronaldo4.png',
#   './dataset/zx/ronaldo\\ronaldo40.png',
#   './dataset/zx/ronaldo\\ronaldo41.png',
#   './dataset/zx/ronaldo\\ronaldo42.png',
#   './dataset/zx/ronaldo\\ronaldo43.png',
#   './dataset/zx/ronaldo\\ronaldo44.png',
#   './dataset/zx/ronaldo\\ronaldo45.png',
#   './dataset/zx/ronaldo\\ronaldo46.png',
#   './dataset/zx/ronaldo\\ronaldo47.png',
#   './dataset/zx/ronaldo\\ronaldo48.png',
#   './dataset/zx/ronaldo\\ronaldo49.png',
#   './dataset/zx/ronaldo\\ronaldo5.png',
#   './dataset/zx/ronaldo\\ronaldo50.png',
#   './dataset/zx/ronaldo\\ronaldo51.png',
#   './dataset/zx/ronaldo\\ronaldo6.png',
#   './dataset/zx/ronaldo\\ronaldo7.png',
#   './dataset/zx/ronaldo\\ronaldo8.png',
#   './dataset/zx/ronaldo\\ronaldo9.png'],
#  'sharapova': ['./dataset/zx/sharapova\\sharapova1.png',
#   './dataset/zx/sharapova\\sharapova10.png',
#   './dataset/zx/sharapova\\sharapova11.png',
#   './dataset/zx/sharapova\\sharapova12.png',
#   './dataset/zx/sharapova\\sharapova13.png',
#   './dataset/zx/sharapova\\sharapova14.png',
#   './dataset/zx/sharapova\\sharapova15.png',
#   './dataset/zx/sharapova\\sharapova16.png',
#   './dataset/zx/sharapova\\sharapova17.png',
#   './dataset/zx/sharapova\\sharapova18.png',
#   './dataset/zx/sharapova\\sharapova19.png',
#   './dataset/zx/sharapova\\sharapova2.png',
#   './dataset/zx/sharapova\\sharapova20.png',
#   './dataset/zx/sharapova\\sharapova21.png',
#   './dataset/zx/sharapova\\sharapova22.png',
#   './dataset/zx/sharapova\\sharapova23.png',
#   './dataset/zx/sharapova\\sharapova24.png',
#   './dataset/zx/sharapova\\sharapova25.png',
#   './dataset/zx/sharapova\\sharapova26.png',
#   './dataset/zx/sharapova\\sharapova27.png',
#   './dataset/zx/sharapova\\sharapova29.png',
#   './dataset/zx/sharapova\\sharapova3.png',
#   './dataset/zx/sharapova\\sharapova30.png',
#   './dataset/zx/sharapova\\sharapova31.png',
#   './dataset/zx/sharapova\\sharapova32.png',
#   './dataset/zx/sharapova\\sharapova4.png',
#   './dataset/zx/sharapova\\sharapova5.png',
#   './dataset/zx/sharapova\\sharapova6.png',
#   './dataset/zx/sharapova\\sharapova8.png',
#   './dataset/zx/sharapova\\sharapova9.png'],
#  'virat_kohli': ['./dataset/zx/virat_kohli\\virat_kohli1.png',
#   './dataset/zx/virat_kohli\\virat_kohli11.png',
#   './dataset/zx/virat_kohli\\virat_kohli12.png',
#   './dataset/zx/virat_kohli\\virat_kohli13.png',
#   './dataset/zx/virat_kohli\\virat_kohli14.png',
#   './dataset/zx/virat_kohli\\virat_kohli15.png',
#   './dataset/zx/virat_kohli\\virat_kohli16.png',
#   './dataset/zx/virat_kohli\\virat_kohli17.png',
#   './dataset/zx/virat_kohli\\virat_kohli19.png',
#   './dataset/zx/virat_kohli\\virat_kohli20.png',
#   './dataset/zx/virat_kohli\\virat_kohli21.png',
#   './dataset/zx/virat_kohli\\virat_kohli22.png',
#   './dataset/zx/virat_kohli\\virat_kohli25.png',
#   './dataset/zx/virat_kohli\\virat_kohli26.png',
#   './dataset/zx/virat_kohli\\virat_kohli27.png',
#   './dataset/zx/virat_kohli\\virat_kohli28.png',
#   './dataset/zx/virat_kohli\\virat_kohli29.png',
#   './dataset/zx/virat_kohli\\virat_kohli3.png',
#   './dataset/zx/virat_kohli\\virat_kohli30.png',
#   './dataset/zx/virat_kohli\\virat_kohli31.png',
#   './dataset/zx/virat_kohli\\virat_kohli32.png',
#   './dataset/zx/virat_kohli\\virat_kohli33.png',
#   './dataset/zx/virat_kohli\\virat_kohli34.png',
#   './dataset/zx/virat_kohli\\virat_kohli35.png',
#   './dataset/zx/virat_kohli\\virat_kohli36.png',
#   './dataset/zx/virat_kohli\\virat_kohli38.png',
#   './dataset/zx/virat_kohli\\virat_kohli39.png',
#   './dataset/zx/virat_kohli\\virat_kohli4.png',
#   './dataset/zx/virat_kohli\\virat_kohli5.png',
#   './dataset/zx/virat_kohli\\virat_kohli6.png',
#   './dataset/zx/virat_kohli\\virat_kohli7.png',
#   './dataset/zx/virat_kohli\\virat_kohli8.png',
#   './dataset/zx/virat_kohli\\virat_kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'messi': 0, 'pandaya': 1, 'ronaldo': 2, 'sharapova': 3, 'virat_kohli': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 45],
#        [ 44],
#        [ 53],
#        ...,
#        [ 15],
#        [  5],
#        [217]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (209, 4096)

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.21.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7924528301886793

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.94      0.86        17
#            1       1.00      0.44      0.62         9
#            2       0.79      0.79      0.79        14
#            3       1.00      0.67      0.80         6
#            4       0.64      1.00      0.78         7
#
#     accuracy                           0.79        53
#    macro avg       0.84      0.77      0.77        53
# weighted avg       0.83      0.79      0.78        53

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.782661
# 1        random_forest    0.576411
# 2  logistic_regression    0.756653
#
#                                    best_params
# 0       {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8867924528301887

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.660377358490566

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8113207547169812

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[16,  0,  1,  0,  0],
#        [ 1,  6,  0,  0,  2],
#        [ 1,  0, 13,  0,  0],
#        [ 0,  0,  1,  5,  0],
#        [ 0,  0,  0,  0,  7]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'messi': 0, 'pandaya': 1, 'ronaldo': 2, 'sharapova': 3, 'virat_kohli': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
